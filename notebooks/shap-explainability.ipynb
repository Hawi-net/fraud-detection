# %%
import joblib

# Load your newly saved model artifact file
model = joblib.load("../models/logistic_regression_model.pkl")

print("Model loaded successfully into SHAP notebook!")
# Out:
# Model loaded successfully into SHAP notebook!
